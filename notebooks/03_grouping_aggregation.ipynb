# %% [markdown]
# # 03 Grouping & Aggregation
# **Agenda for this notebook:**
#
# - Load the cleaned dataset
# - Calculate key business metrics (Revenue, Average Price, etc.)
# - Group by Make, Year, City, Transmission, etc.
# - Create useful summaries for price prediction insights
# - Identify patterns that affect car prices
#
# **Project Notebooks Plan:**
#
# 1. 01_data_loading.ipynb ← Completed
# 2. 02_data_cleaning.ipynb ← Completed
# 3. 03_grouping_aggregation.ipynb ← Current
# 4. 04_feature_engineering.ipynb
# 5. 05_visualization.ipynb
