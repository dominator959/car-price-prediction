# %% [markdown]
# # 01 Data Loading
#
# ## Job of this notebook
# - Load the raw car dataset into a pandas DataFrame
# - Perform an initial inspection (shape, columns, dtypes, missing values)
# - Understand what we are working with before any cleaning

# %% [markdown]
# ## Import pandas and load the data
#
# ### pd.read_csv()
# - What it does: Reads a CSV file from disk and returns a DataFrame
#
# - Why we use it here: It’s the standard way to load tabular data in pandas
#
# - What to expect: A DataFrame object with rows and columns

# %% [markdown]
# ### df.head()
# - What it does: Displays the first 5 rows of the loaded DataFrame by default.
#
# - Why we use it here: To visually verify that the PakWheels dataset loaded correctly and to get our first look at the columns and data formats.
#
# - What to expect from it: A HTML table displaying the first 5 records of the dataset with all available columns.

# %%
import pandas as pd
df = pd.read_csv('../data/raw/pakwheels_listing_dataset.csv')
df.head()
# Out:
#                                                title  \
# 0         Honda N Box  2022 Custom GL for Sale9.7/10
# 1                 Honda N Wgn  2023 L for Sale9.5/10
# 2             Toyota Hilux  2004 Double Cab for Sale
# 3  Toyota Hilux  2017 Revo V Automatic 3.0  for Sale
# 4    Honda Civic  2019 Oriel 1.8 i-VTEC CVT for Sale
#
#                                                  url           price    year  \
# 0  https://www.pakwheels.com/used-cars/honda-n-bo...  PKR 38.75 lacs  2022.0
# 1  https://www.pakwheels.com/used-cars/honda-n-wg...  PKR 40.25 lacs  2023.0
# 2  https://www.pakwheels.com/used-cars/toyota-hil...     PKR 35 lacs  2004.0
# 3  https://www.pakwheels.com/used-cars/toyota-hil...   PKR 88.5 lacs  2017.0
# 4  https://www.pakwheels.com/used-cars/honda-civi...  PKR 56.85 lacs  2019.0
#
#       mileage   engine transmission fuel_type        city seller_type  \
# 0   19,198 km   660 cc    Automatic    Petrol      Lahore  Individual
# ...

# %% [markdown]
# #### Output Interpretation:
#
# Data Science & Business Translation: This is our first critical sanity check. In a PakWheels car price dataset, we expect to see structural columns such as Price, Year, Engine Capacity, Mileage, and Transmission. Looking at these first 5 rows allows us to instantly spot obvious formatting challenges—such as text mixed with numbers (e.g., "150,000 km" or "1300 cc")—which will dictate our strategy for the cleaning notebook later.

# %% [markdown]
# # df.shape and df.info()
# - df.shape returns (rows, columns) — tells us the size of the data
#
# - df.info() gives column names, non-null counts, and dtypes — reveals missing data and wrong types
#
# - We use both here to quantify what we’re dealing with before cleaning

# %%
# Shape of the dataset: rows × columns
print("Shape:", df.shape)
print(" -" * 30)

# Data types and non-null counts
df.info()
# Out:
# Shape: (1394, 18)
#  - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1394 entries, 0 to 1393
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         1331 non-null   object
#  1   url           1331 non-null   object
#  2   price         1331 non-null   object
#  3   year          1331 non-null   float64
#  4   mileage       1331 non-null   object
#  5   engine        605 non-null    object
#  6   transmission  605 non-null    object
#  7   fuel_type     1331 non-null   object
#  8   city          1331 non-null   object
#  9   seller_type   1331 non-null   object
#  10  ad_id         1331 non-null   object
#  11  posted_date   1331 non-null   object
#  12  scraped_at    1331 non-null   object
#  13  source_type   1331 non-null   object
#  14  source_url    1331 non-null   object
#  15  make          0 non-null      float64
# ...

# %% [markdown]
# ### When we analyze the output of df.shape and df.info() together, we establish the baseline engineering constraints and business scope of the PakWheels dataset.
#
# #### Here is what these two outputs explicitly reveal about our project:
#
# - Data Volume & Commercial Scope: df.shape provides the exact volume of the market sample. A high row count means we have a representative sample of the Pakistani automotive market, capturing diverse transactions across different cities (e.g., Lahore, Karachi, Islamabad).
#
# - The Cleaning Roadmap (The "Object" Trap): df.info() reveals the storage data types. If critical numeric features like Price, Mileage, and Engine Capacity are classified as object (text) data types, it means they contain non-numeric characters (such as "PKR", "lacs", "km", and "cc"). We cannot build a prediction model on text. This confirms that Notebook 02 must focus heavily on string parsing and type casting.
#
# - Missing Data Inventory: By comparing the total rows from df.shape against the "Non-Null Count" in df.info(), we instantly spot columns with missing values. Features with significant missing data will require business logic decisions: do we drop those car listings, or do we fill them using statistical averages (imputation)?

# %% [markdown]
# # df.duplicated().sum()
# - What it does: Identifies identical rows across the entire dataset and returns the total count of these duplicate records.
#
# - Why we use it here: Duplicate listings often occur on web platforms like PakWheels when users re-post the same ad or during data scraping. We need to quantify this noise.
#
# - What to expect from it: A single integer representing the total number of duplicate rows found.

# %%
df.duplicated().sum()
# Out:
# np.int64(62)

# %% [markdown]
# ##### If this number is greater than zero, it means we have redundant information.
# - Keeping duplicate rows skews our statistical analysis and gives the machine learning model false confidence by testing it on data it has already seen. We record this number now; we will explicitly drop these duplicates in Notebook 02.

# %% [markdown]
# # df.to_csv()
# - What it does: Exports the current DataFrame from the Python session back into a CSV file on your hard drive.
#
# - Why we use it here: To finalize the data loading phase. Even though we haven't changed the data yet, we save it into the data/processed/ directory to establish our professional workflow pipelines. This ensures our raw data remains untouched and pristine.
#
# - What to expect from it: A silent execution that writes a new file named 01_loaded_raw_data.csv into your processed data folder.

# %%
# Save the loaded data to the processed directory to start our pipeline
output_path = "../data/processed/01_loaded_raw_data.csv"
df.to_csv(output_path, index=False)

# %% [markdown]
# - Setting index=False prevents Pandas from creating an unnecessary extra column of numbers (0, 1, 2...) in our new file. We have successfully completed the data loading stage. Our raw data remains 100% secure in data/raw/, and we now have a standard starting file for our next notebook.
